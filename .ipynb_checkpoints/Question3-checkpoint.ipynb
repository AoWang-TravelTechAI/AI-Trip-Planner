# %%
# Name: Ao Wang
# CWID: 20033397
# Question 3

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("hepatitis_A.csv")

# %%
# Select numerical columns for summary
numerical_columns = ["BILIRUBIN", "SGOT", "ALBUMIN"]

# Generate summary statistics (min, max, mean, etc.)
summary = df[numerical_columns].describe()
print("Summary Statistics:")
print(summary)
# Out:
# Summary Statistics:
#         BILIRUBIN       SGOT     ALBUMIN
# count  149.000000  151.00000  139.000000
# mean     1.427517   85.89404    3.817266
# std      1.212149   89.65089    0.651523
# min      0.300000   14.00000    2.100000
# 25%      0.700000   31.50000    3.400000
# 50%      1.000000   58.00000    4.000000
# 75%      1.500000  100.50000    4.200000
# max      8.000000  648.00000    6.400000

# %%
# Create scatter plots for pairs of numerical columns
print("Scatter Plots:")
sns.pairplot(df[numerical_columns])
plt.show()
# Out:
# Scatter Plots:

# %%
# Create box plots for numerical columns
print("Box Plots:")
plt.figure(figsize=(12, 6))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(1, 3, i)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.show()
# Out:
# Box Plots:
